# %%
import pandas as pd

df = pd.read_csv('../data/universal_top_spotify_songs.csv')
df = df.drop(columns=['spotify_id', 'daily_rank', 'daily_movement', 'weekly_movement', 'snapshot_date', 'name', 'album_release_date', 'album_name'])

countries = ['GB', 'DE', 'FR', 'ES', 'IT', 'NL', 'SE', 'PL', 'BE', 'PT']

df = df[df['country'].isin(countries)]
df = df.groupby('country').head(500)


df

# %%
df.to_csv('../data/top_spotify_songs_EU_cleaned.csv', index=False) #remove index

# %%
##Continued Cleaning

df = pd.read_csv('../data/top_spotify_songs_EU_cleaned.csv')
df.head(5)

# %%
df['duration_s'] = df['duration_ms'] / 1000
df = df.drop(columns=['duration_ms'])

# %%
df['artist_count'] = df['artists'].str.split(',').str.len()
# Out:
#                            artists country  popularity  is_explicit  \
# 0           Tjuvjakt, Fanny Avonne      SE          76        False
# 1                         Ida-Lova      SE          77        False
# 2                             Lov1      SE          64        False
# 3                              KAJ      SE          75        False
# 4  Humlan Djojj, Josefine Götestam      SE          76        False
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.735  0.6530    3    -6.261     1       0.0533        0.3600
# 1         0.404  0.6830    1    -6.969     1       0.0594        0.3020
# 2         0.695  0.6760    8    -6.859     1       0.0384        0.1010
# 3         0.757  0.8890    9    -4.729     0       0.0788        0.0754
# 4         0.684  0.0326    0   -17.898     1       0.0583        0.9730
#
#    instrumentalness  liveness  valence    tempo  time_signature  duration_s  \
# 0          0.000000    0.0791    0.620  116.002               4     190.344
# 1          0.000000    0.3180    0.661  162.091               4     187.076
# 2          0.000000    0.0929    0.431  121.962               4     208.201
# 3          0.000023    0.0397    0.754  106.037               4     166.880
# 4          0.000002    0.1080    0.440   66.685               5     140.046
#
#    artist_count
# 0             2
# 1             1
# 2             1
# 3             1
# 4             2

# %%
print(max(df['artist_count']))
df['artists'] = df['artists'].str.lower()
df['artists_list'] = df['artists'].str.split(', ')

df_exploded = df.explode('artists_list')
# Out:
# 7

# %%
df.head(5)
# Out:
#                            artists country  popularity  is_explicit  \
# 0           tjuvjakt, fanny avonne      SE          76        False
# 1                         ida-lova      SE          77        False
# 2                             lov1      SE          64        False
# 3                              kaj      SE          75        False
# 4  humlan djojj, josefine götestam      SE          76        False
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.735  0.6530    3    -6.261     1       0.0533        0.3600
# 1         0.404  0.6830    1    -6.969     1       0.0594        0.3020
# 2         0.695  0.6760    8    -6.859     1       0.0384        0.1010
# 3         0.757  0.8890    9    -4.729     0       0.0788        0.0754
# 4         0.684  0.0326    0   -17.898     1       0.0583        0.9730
#
#    instrumentalness  liveness  valence    tempo  time_signature  duration_s  \
# 0          0.000000    0.0791    0.620  116.002               4     190.344
# 1          0.000000    0.3180    0.661  162.091               4     187.076
# 2          0.000000    0.0929    0.431  121.962               4     208.201
# 3          0.000023    0.0397    0.754  106.037               4     166.880
# 4          0.000002    0.1080    0.440   66.685               5     140.046
#
#    artist_count                       artists_list
# 0             2           [tjuvjakt, fanny avonne]
# 1             1                         [ida-lova]
# 2             1                             [lov1]
# 3             1                              [kaj]
# 4             2  [humlan djojj, josefine götestam]

# %%
df.to_csv('../data/fully_cleaned_top_spotify_songs_EU.csv', index=False) #cleaned new df
