# %%
import pandas as pd
import altair as alt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2 import altair as alt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
euro_df = pd.read_csv('fully_cleaned_top_spotify_songs_EU.csv')
euro_df
# Out:
#                                 artists country  popularity  is_explicit  \
# 0                tjuvjakt, fanny avonne      SE          76        False
# 1                              ida-lova      SE          77        False
# 2                                  lov1      SE          64        False
# 3                                   kaj      SE          75        False
# 4       humlan djojj, josefine götestam      SE          76        False
# ...                                 ...     ...         ...          ...
# 4995                      chappell roan      GB          48        False
# 4996                        central cee      GB          36         True
# 4997                        myles smith      GB          75        False
# 4998  pawsa, the adventures of stevie v      GB          81        False
# 4999                kendrick lamar, sza      GB          88        False
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# ...
