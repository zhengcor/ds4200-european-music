# %%
import pandas as pd

df = pd.read_csv('universal_top_spotify_songs.csv')
df = df.drop(columns=['spotify_id', 'daily_rank', 'daily_movement', 'weekly_movement', 'snapshot_date', 'name', 'album_release_date', 'album_name'])

countries = ['GB', 'DE', 'FR', 'ES', 'IT', 'NL', 'SE', 'PL', 'BE', 'PT']

df = df[df['country'].isin(countries)]
df = df.groupby('country').head(500)


df
# Out:
#                                   artists country  popularity  is_explicit  \
# 650                Tjuvjakt, Fanny Avonne      SE          76        False
# 651                              Ida-Lova      SE          77        False
# 652                                  Lov1      SE          64        False
# 653                                   KAJ      SE          75        False
# 654       Humlan Djojj, Josefine Götestam      SE          76        False
# ...                                   ...     ...         ...          ...
# 467263                      Chappell Roan      GB          48        False
# 467264                        Central Cee      GB          36         True
# 467265                        Myles Smith      GB          75        False
# 467266  PAWSA, The Adventures Of Stevie V      GB          81        False
# 467267                Kendrick Lamar, SZA      GB          88        False
#
#         duration_ms  danceability  energy  key  loudness  mode  speechiness  \
# 650          190344         0.735  0.6530    3    -6.261     1       0.0533
# 651          187076         0.404  0.6830    1    -6.969     1       0.0594
# 652          208201         0.695  0.6760    8    -6.859     1       0.0384
# 653          166880         0.757  0.8890    9    -4.729     0       0.0788
# 654          140046         0.684  0.0326    0   -17.898     1       0.0583
# ...             ...           ...     ...  ...       ...   ...          ...
# 467263       184841         0.742  0.7570    6    -4.981     1       0.0421
# 467264       198400         0.750  0.7370   11    -4.245     0       0.3000
# 467265       176000         0.762  0.7830    5    -5.206     0       0.0387
# 467266       221448         0.783  0.4730    0    -6.493     1       0.1670
# 467267       177598         0.707  0.5750    2    -7.546     1       0.1250
#
#         acousticness  instrumentalness  liveness  valence    tempo  \
# 650           0.3600          0.000000    0.0791    0.620  116.002
# 651           0.3020          0.000000    0.3180    0.661  162.091
# 652           0.1010          0.000000    0.0929    0.431  121.962
# 653           0.0754          0.000023    0.0397    0.754  106.037
# 654           0.9730          0.000002    0.1080    0.440   66.685
# ...              ...               ...       ...      ...      ...
# 467263        0.0187          0.000000    0.3050    0.957  139.982
# 467264        0.4450          0.000000    0.0772    0.962  142.402
# 467265        0.3290          0.000000    0.0536    0.840  115.091
# 467266        0.0693          0.000034    0.1490    0.539  131.890
# 467267        0.2510          0.000000    0.2480    0.576  138.008
#
#         time_signature
# 650                  4
# 651                  4
# 652                  4
# 653                  4
# 654                  5
# ...                ...
# 467263               4
# 467264               4
# 467265               4
# 467266               4
# 467267               4
#
# [5000 rows x 17 columns]

# %%
df.to_csv('top_spotify_songs_EU_cleaned.csv', index=False) #remove index

# %%
##Continued Cleaning

df = pd.read_csv('top_spotify_songs_EU_cleaned.csv')
df.head(5)
# Out:
#                            artists country  popularity  is_explicit  \
# 0           Tjuvjakt, Fanny Avonne      SE          76        False
# 1                         Ida-Lova      SE          77        False
# 2                             Lov1      SE          64        False
# 3                              KAJ      SE          75        False
# 4  Humlan Djojj, Josefine Götestam      SE          76        False
#
#    duration_ms  danceability  energy  key  loudness  mode  speechiness  \
# 0       190344         0.735  0.6530    3    -6.261     1       0.0533
# 1       187076         0.404  0.6830    1    -6.969     1       0.0594
# 2       208201         0.695  0.6760    8    -6.859     1       0.0384
# 3       166880         0.757  0.8890    9    -4.729     0       0.0788
# 4       140046         0.684  0.0326    0   -17.898     1       0.0583
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 0        0.3600          0.000000    0.0791    0.620  116.002               4
# 1        0.3020          0.000000    0.3180    0.661  162.091               4
# 2        0.1010          0.000000    0.0929    0.431  121.962               4
# 3        0.0754          0.000023    0.0397    0.754  106.037               4
# 4        0.9730          0.000002    0.1080    0.440   66.685               5

# %%
df['duration_s'] = df['duration_ms'] / 1000
df = df.drop(columns=['duration_ms'])

# %%
df['artist_count'] = df['artists'].str.split(',').str.len()
# Out:
#                            artists country  popularity  is_explicit  \
# 0           Tjuvjakt, Fanny Avonne      SE          76        False
# 1                         Ida-Lova      SE          77        False
# 2                             Lov1      SE          64        False
# 3                              KAJ      SE          75        False
# 4  Humlan Djojj, Josefine Götestam      SE          76        False
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.735  0.6530    3    -6.261     1       0.0533        0.3600
# 1         0.404  0.6830    1    -6.969     1       0.0594        0.3020
# 2         0.695  0.6760    8    -6.859     1       0.0384        0.1010
# 3         0.757  0.8890    9    -4.729     0       0.0788        0.0754
# 4         0.684  0.0326    0   -17.898     1       0.0583        0.9730
#
#    instrumentalness  liveness  valence    tempo  time_signature  duration_s  \
# 0          0.000000    0.0791    0.620  116.002               4     190.344
# 1          0.000000    0.3180    0.661  162.091               4     187.076
# 2          0.000000    0.0929    0.431  121.962               4     208.201
# 3          0.000023    0.0397    0.754  106.037               4     166.880
# 4          0.000002    0.1080    0.440   66.685               5     140.046
#
#    artist_count
# 0             2
# 1             1
# 2             1
# 3             1
# 4             2

# %%
print(max(df['artist_count']))
df['artists'] = df['artists'].str.lower()
df['artists_list'] = df['artists'].str.split(', ')

df_exploded = df.explode('artists_list')
# Out:
# 7

# %%
df.head(5)
df
# Out:
#                                   artists country  popularity  is_explicit  \
# 650                Tjuvjakt, Fanny Avonne      SE          76        False
# 651                              Ida-Lova      SE          77        False
# 652                                  Lov1      SE          64        False
# 653                                   KAJ      SE          75        False
# 654       Humlan Djojj, Josefine Götestam      SE          76        False
# ...                                   ...     ...         ...          ...
# 467263                      Chappell Roan      GB          48        False
# 467264                        Central Cee      GB          36         True
# 467265                        Myles Smith      GB          75        False
# 467266  PAWSA, The Adventures Of Stevie V      GB          81        False
# 467267                Kendrick Lamar, SZA      GB          88        False
#
#         duration_ms  danceability  energy  key  loudness  mode  speechiness  \
# 650          190344         0.735  0.6530    3    -6.261     1       0.0533
# 651          187076         0.404  0.6830    1    -6.969     1       0.0594
# 652          208201         0.695  0.6760    8    -6.859     1       0.0384
# 653          166880         0.757  0.8890    9    -4.729     0       0.0788
# 654          140046         0.684  0.0326    0   -17.898     1       0.0583
# ...             ...           ...     ...  ...       ...   ...          ...
# 467263       184841         0.742  0.7570    6    -4.981     1       0.0421
# 467264       198400         0.750  0.7370   11    -4.245     0       0.3000
# 467265       176000         0.762  0.7830    5    -5.206     0       0.0387
# 467266       221448         0.783  0.4730    0    -6.493     1       0.1670
# 467267       177598         0.707  0.5750    2    -7.546     1       0.1250
#
#         acousticness  instrumentalness  liveness  valence    tempo  \
# 650           0.3600          0.000000    0.0791    0.620  116.002
# 651           0.3020          0.000000    0.3180    0.661  162.091
# 652           0.1010          0.000000    0.0929    0.431  121.962
# 653           0.0754          0.000023    0.0397    0.754  106.037
# 654           0.9730          0.000002    0.1080    0.440   66.685
# ...              ...               ...       ...      ...      ...
# 467263        0.0187          0.000000    0.3050    0.957  139.982
# 467264        0.4450          0.000000    0.0772    0.962  142.402
# 467265        0.3290          0.000000    0.0536    0.840  115.091
# 467266        0.0693          0.000034    0.1490    0.539  131.890
# 467267        0.2510          0.000000    0.2480    0.576  138.008
#
#         time_signature
# 650                  4
# 651                  4
# 652                  4
# 653                  4
# 654                  5
# ...                ...
# 467263               4
# 467264               4
# 467265               4
# 467266               4
# 467267               4
#
# [5000 rows x 17 columns]

# %%
df.to_csv('fully_cleaned_top_spotify_songs_EU.csv', index=False) #cleaned new df
