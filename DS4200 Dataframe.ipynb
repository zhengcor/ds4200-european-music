# %%
import pandas as pd

df = pd.read_csv('universal_top_spotify_songs.csv')
df = df.drop(columns=['spotify_id', 'daily_rank', 'daily_movement', 'weekly_movement', 'snapshot_date'])

countries = ['GB', 'DE', 'FR', 'ES', 'IT', 'NL', 'SE', 'PL', 'BE', 'PT']

df = df[df['country'].isin(countries)]
df = df.groupby('country').head(500)


df
# Out:
#                             name                            artists country  \
# 650                  Tusen spänn             Tjuvjakt, Fanny Avonne      SE
# 651               Svagare än jag                           Ida-Lova      SE
# 652                   Sommarkatt                               Lov1      SE
# 653              Bara Bada Bastu                                KAJ      SE
# 654             Djurens vaggvisa    Humlan Djojj, Josefine Götestam      SE
# ...                          ...                                ...     ...
# 467263                HOT TO GO!                      Chappell Roan      GB
# 467264          Walk In Wardrobe                        Central Cee      GB
# 467265          Nice To Meet You                        Myles Smith      GB
# 467266  Dirty Cash (Money Talks)  PAWSA, The Adventures Of Stevie V      GB
# 467267         luther (with sza)                Kendrick Lamar, SZA      GB
#
#         popularity  is_explicit  duration_ms  \
# 650             76        False       190344
# 651             77        False       187076
# 652             64        False       208201
# 653             75        False       166880
# 654             76        False       140046
# ...            ...          ...          ...
# 467263          48        False       184841
# 467264          36         True       198400
# 467265          75        False       176000
# 467266          81        False       221448
# 467267          88        False       177598
#
#                                      album_name album_release_date  \
# 650                                 Tusen spänn         2025-05-09
# 651                              Svagare än jag         2025-04-11
# 652                                  Sommarkatt         2025-05-30
# 653                            Sauna Collection         2025-05-09
# 654                      Somna med Humlan Djojj         2020-10-30
# ...                                         ...                ...
# 467263  The Rise and Fall of a Midwest Princess         2023-09-21
# 467264                     CAN'T RUSH GREATNESS         2025-01-24
# 467265     Nice To Meet You (Mistletoe Version)         2024-12-13
# 467266                 Dirty Cash (Money Talks)         2024-11-15
# 467267                                      GNX         2024-11-21
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 650            0.735  0.6530    3    -6.261     1       0.0533        0.3600
# 651            0.404  0.6830    1    -6.969     1       0.0594        0.3020
# 652            0.695  0.6760    8    -6.859     1       0.0384        0.1010
# 653            0.757  0.8890    9    -4.729     0       0.0788        0.0754
# 654            0.684  0.0326    0   -17.898     1       0.0583        0.9730
# ...              ...     ...  ...       ...   ...          ...           ...
# 467263         0.742  0.7570    6    -4.981     1       0.0421        0.0187
# 467264         0.750  0.7370   11    -4.245     0       0.3000        0.4450
# 467265         0.762  0.7830    5    -5.206     0       0.0387        0.3290
# 467266         0.783  0.4730    0    -6.493     1       0.1670        0.0693
# 467267         0.707  0.5750    2    -7.546     1       0.1250        0.2510
#
#         instrumentalness  liveness  valence    tempo  time_signature
# 650             0.000000    0.0791    0.620  116.002               4
# 651             0.000000    0.3180    0.661  162.091               4
# 652             0.000000    0.0929    0.431  121.962               4
# 653             0.000023    0.0397    0.754  106.037               4
# 654             0.000002    0.1080    0.440   66.685               5
# ...                  ...       ...      ...      ...             ...
# 467263          0.000000    0.3050    0.957  139.982               4
# 467264          0.000000    0.0772    0.962  142.402               4
# 467265          0.000000    0.0536    0.840  115.091               4
# 467266          0.000034    0.1490    0.539  131.890               4
# 467267          0.000000    0.2480    0.576  138.008               4
#
# [5000 rows x 20 columns]
